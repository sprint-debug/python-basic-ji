# %% [markdown]
# ## 1. Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls -al '/gdrive/My Drive/data'
# Out:
# total 24952
# -rw------- 1 root root 12880798 Aug  2 06:21 marathon_2015_2017.csv
# -rw------- 1 root root  4228123 Sep 20  2019 marathon_results_2015.csv
# -rw------- 1 root root  4244383 Sep 20  2019 marathon_results_2016.csv
# -rw------- 1 root root  4196246 Sep 20  2019 marathon_results_2017.csv

# %% [markdown]
# ## 2. Import Data

# %%
import pandas as pd

# %%
marathon_2017 = pd.read_csv('/gdrive/My Drive/data/marathon_results_2017.csv')

# %%
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      25K      30K      35K      40K     Pace  \
# 0     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
marathon_2017.tail()
# Out:
#        Unnamed: 0    Bib                      Name  Age M/F          City  \
# 26405       26405  25166  Steinbach, Paula Eyvonne   61   F       Ontario
# 26406       26406  25178        Avelino, Andrew R.   25   M  Fayetteville
# 26407       26407  27086           Hantel, Johanna   57   F       Malvern
# 26408       26408  25268              Reilly, Bill   64   M      New York
# 26409       26409  25266             Rigsby, Scott   48   M    Alpharetta
#
#       State Country Citizen Unnamed: 9  ...      25K      30K      35K  \
# 26405    CA     USA     NaN         MI  ...  4:12:06  5:03:08  5:55:18
# 26406    NC     USA     NaN         MI  ...  3:50:19  4:50:01  5:53:48
# 26407    PA     USA     NaN        NaN  ...  4:15:21  5:06:37  6:00:33
# 26408    NY     USA     NaN         MI  ...  4:06:10  5:07:09  6:06:07
# 26409    GA     USA     NaN         MI  ...  4:27:14  5:37:13  6:39:07
#
#            40K     Pace Proj Time Official Time Overall Gender Division
# ...

# %%
marathon_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     26410 non-null  int64
#  1   Bib            26410 non-null  object
#  2   Name           26410 non-null  object
#  3   Age            26410 non-null  int64
#  4   M/F            26410 non-null  object
#  5   City           26410 non-null  object
#  6   State          22815 non-null  object
#  7   Country        26410 non-null  object
#  8   Citizen        1254 non-null   object
#  9   Unnamed: 9     91 non-null     object
#  10  5K             26410 non-null  object
#  11  10K            26410 non-null  object
#  12  15K            26410 non-null  object
#  13  20K            26410 non-null  object
#  14  Half           26410 non-null  object
#  15  25K            26410 non-null  object
#  16  30K            26410 non-null  object
# ...

# %% [markdown]
# ## 3. Data Cleansing

# %%
#Checking the null values in the data fields
marathon_2017.isnull().sum(axis=0)
# Out:
# Unnamed: 0           0
# Bib                  0
# Name                 0
# Age                  0
# M/F                  0
# City                 0
# State             3595
# Country              0
# Citizen          25156
# Unnamed: 9       26319
# 5K                   0
# 10K                  0
# 15K                  0
# 20K                  0
# Half                 0
# 25K                  0
# 30K                  0
# 35K                  0
# 40K                  0
# Pace                 0
# Proj Time            0
# Official Time        0
# Overall              0
# Gender               0
# Division             0
# dtype: int64

# %%
#Show columns of the data frame
marathon_2017.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
marathon_2017_clean = marathon_2017.drop(['Unnamed: 0','Bib','Unnamed: 9'], axis='columns')

# %%
marathon_2017_clean.head()
# Out:
#                Name  Age M/F           City State Country Citizen       5K  \
# 0   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN  0:15:25
# 1       Rupp, Galen   30   M       Portland    OR     USA     NaN  0:15:24
# 2     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN  0:15:25
# 3  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN  0:15:25
# 4    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN  0:15:25
#
#        10K      15K  ...      25K      30K      35K      40K     Pace  \
# 0  0:30:28  0:45:44  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1  0:30:27  0:45:44  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2  0:30:29  0:45:44  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3  0:30:29  0:45:44  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4  0:30:28  0:45:44  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender  Division
# ...

# %%
marathon_2017_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           26410 non-null  object
#  1   Age            26410 non-null  int64
#  2   M/F            26410 non-null  object
#  3   City           26410 non-null  object
#  4   State          22815 non-null  object
#  5   Country        26410 non-null  object
#  6   Citizen        1254 non-null   object
#  7   5K             26410 non-null  object
#  8   10K            26410 non-null  object
#  9   15K            26410 non-null  object
#  10  20K            26410 non-null  object
#  11  Half           26410 non-null  object
#  12  25K            26410 non-null  object
#  13  30K            26410 non-null  object
#  14  35K            26410 non-null  object
#  15  40K            26410 non-null  object
#  16  Pace           26410 non-null  object
# ...

# %% [markdown]
# #4. Data Selection

# %%
name = marathon_2017_clean.Name

# %%
name
# Out:
# 0                 Kirui, Geoffrey
# 1                     Rupp, Galen
# 2                   Osako, Suguru
# 3                Biwott, Shadrack
# 4                  Chebet, Wilson
#                    ...
# 26405    Steinbach, Paula Eyvonne
# 26406          Avelino, Andrew R.
# 26407             Hantel, Johanna
# 26408                Reilly, Bill
# 26409               Rigsby, Scott
# Name: Name, Length: 26410, dtype: object

# %%
official_time = marathon_2017_clean['Official Time']

# %%
official_time
# Out:
# 0        2:09:37
# 1        2:09:58
# 2        2:10:28
# 3        2:12:08
# 4        2:12:35
#           ...
# 26405    7:09:39
# 26406    7:16:59
# 26407    7:19:37
# 26408    7:20:44
# 26409    7:58:14
# Name: Official Time, Length: 26410, dtype: object

# %%
marathon_2017_selection = pd.DataFrame(marathon_2017_clean, columns=['Name', 'Age',	'M/F',	'City',	'State'])

# %%
marathon_2017_selection
# Out:
#                            Name  Age M/F           City State
# 0               Kirui, Geoffrey   24   M       Keringet   NaN
# 1                   Rupp, Galen   30   M       Portland    OR
# 2                 Osako, Suguru   25   M   Machida-City   NaN
# 3              Biwott, Shadrack   32   M  Mammoth Lakes    CA
# 4                Chebet, Wilson   31   M       Marakwet   NaN
# ...                         ...  ...  ..            ...   ...
# 26405  Steinbach, Paula Eyvonne   61   F        Ontario    CA
# 26406        Avelino, Andrew R.   25   M   Fayetteville    NC
# 26407           Hantel, Johanna   57   F        Malvern    PA
# 26408              Reilly, Bill   64   M       New York    NY
# 26409             Rigsby, Scott   48   M     Alpharetta    GA
#
# [26410 rows x 5 columns]

# %%
seniors = marathon_2017_clean.Age > 60

# %%
seniors
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26405     True
# 26406    False
# 26407    False
# 26408     True
# 26409    False
# Name: Age, Length: 26410, dtype: bool

# %%
seniors_selection = marathon_2017_clean[marathon_2017_clean.Age > 60]

# %%
seniors_selection
# Out:
#                            Name  Age M/F           City State Country Citizen  \
# 1676          Bariyanga, Joseph   61   M       Mililani    HI     USA     NaN
# 1802            Funk, Dennis L.   61   M          Greer    SC     USA     NaN
# 1949          Beasley, Steve G.   61   M       Goderich    ON     CAN     NaN
# 2731                Dykes, Gene   69   M    Bala Cynwyd    PA     USA     NaN
# 2863          Standerfer, Joe L   61   M  Winston-Salem    NC     USA     NaN
# ...                         ...  ...  ..            ...   ...     ...     ...
# 26397        Coffman, Steven D.   69   M  East Sandwich    MA     USA     NaN
# 26398           Scholtz, Theo E   70   M          Wylie    TX     USA     NaN
# 26401       Elliott, Gregory J.   68   M        Chicago    IL     USA     NaN
# 26405  Steinbach, Paula Eyvonne   61   F        Ontario    CA     USA     NaN
# 26408              Reilly, Bill   64   M       New York    NY     USA     NaN
#
# ...

# %%
(marathon_2017_clean.Age > 60).unique()
# Out:
# array([False,  True])

# %%
marathon_2017_clean.Country.unique()
# Out:
# array(['KEN', 'USA', 'JPN', 'ETH', 'ZIM', 'MEX', 'BRN', 'BRA', 'CAN',
#        'ITA', 'NED', 'IRL', 'BDI', 'GBR', 'GER', 'ESP', 'SUI', 'COL',
#        'NOR', 'POL', 'FRA', 'RUS', 'POR', 'CRC', 'BEL', 'NZL', 'PER',
#        'DOM', 'PAN', 'AUS', 'DEN', 'MAS', 'PHI', 'CHI', 'AUT', 'ARG',
#        'SIN', 'CHN', 'TWN', 'GUA', 'RSA', 'HKG', 'SLO', 'EST', 'TUR',
#        'EGY', 'IND', 'UAE', 'SWE', 'BER', 'KOR', 'CAY', 'FIN', 'LTU',
#        'GRE', 'CRO', 'ISL', 'LUX', 'FLK', 'VEN', 'JAM', 'THA', 'HON',
#        'SRB', 'CZE', 'ISR', 'MLT', 'HUN', 'ECU', 'KSA', 'ESA', 'MAR',
#        'ROU', 'LAT', 'UKR', 'SMR', 'BUL', 'ALG', 'NCA', 'SVK', 'AND',
#        'BAR', 'INA', 'GRN', 'URU', 'PAR', 'TCA', 'KUW', 'TRI', 'MGL',
#        'NGR'], dtype=object)

# %%
KEN_runner = marathon_2017_clean[marathon_2017_clean.Country == 'KEN']

# %%
KEN_runner
# Out:
#                    Name  Age M/F         City State Country Citizen       5K  \
# 0       Kirui, Geoffrey   24   M     Keringet   NaN     KEN     NaN  0:15:25
# 4        Chebet, Wilson   31   M     Marakwet   NaN     KEN     NaN  0:15:25
# 14        Korir, Wesley   34   M       Kitale   NaN     KEN     NaN  0:15:24
# 17      Mutai, Emmanuel   32   M       Lessos   NaN     KEN     NaN  0:15:24
# 20       Kiplagat, Edna   37   F  Uasin Gishu   NaN     KEN     NaN  0:17:46
# 43      Cherono, Gladys   33   F      Kericho   NaN     KEN     NaN  0:17:45
# 53  Kipketer, Valentine   24   F        Keiyo   NaN     KEN     NaN  0:17:45
# 69       Kosgei, Brigid   23   F      Kapsait   NaN     KEN     NaN  0:17:45
#
#         10K      15K  ...      25K      30K      35K      40K     Pace  \
# 0   0:30:28  0:45:44  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 4   0:30:28  0:45:44  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
# ...

# %%
marathon_2017_clean_north_america = marathon_2017_clean[marathon_2017_clean.Country.isin(['USA', 'CAN'])]

# %%
marathon_2017_clean_north_america
# Out:
#                            Name  Age M/F              City State Country  \
# 1                   Rupp, Galen   30   M          Portland    OR     USA
# 3              Biwott, Shadrack   32   M     Mammoth Lakes    CA     USA
# 5              Abdirahman, Abdi   40   M           Phoenix    AZ     USA
# 6            Maiyo, Augustus K.   33   M  Colorado Springs    CO     USA
# 8                Puskedra, Luke   27   M            Eugene    OR     USA
# ...                         ...  ...  ..               ...   ...     ...
# 26405  Steinbach, Paula Eyvonne   61   F           Ontario    CA     USA
# 26406        Avelino, Andrew R.   25   M      Fayetteville    NC     USA
# 26407           Hantel, Johanna   57   F           Malvern    PA     USA
# 26408              Reilly, Bill   64   M          New York    NY     USA
# 26409             Rigsby, Scott   48   M        Alpharetta    GA     USA
#
#       Citizen       5K      10K      15K  ...      25K      30K      35K  \
# ...

# %% [markdown]
# #5. Insert Data

# %%
marathon_2017_selection.value_counts()
# Out:
# Name                      Age  M/F  City           State
# Aakre, Katie A.           27   F    St. Paul       MN       1
# O'Brien, Sean             54   M    Los Angeles    CA       1
# O'Connor, Frederick       38   M    Boston         MA       1
# O'Connor, Francis X.      50   M    Aurora         IL       1
# O'Connor, Eileen          46   F    West Roxbury   MA       1
#                                                            ..
# Gonzales, Anthony O.      52   M    Tucson         AZ       1
# Gonzales Nagels, Nicolas  41   M    The Woodlands  TX       1
# Gonyea, Jennifer          46   F    Maplewood      NJ       1
# Gonthier, Lucie           39   F    Québec         QC       1
# deQuintal, Ryan W.        21   M    Nazareth       PA       1
# Length: 22815, dtype: int64

# %%
marathon_2017_count = pd.DataFrame(marathon_2017_clean, columns=['Age',	'M/F'])

# %%
marathon_2017_count.value_counts()
# Out:
# Age  M/F
# 45   M      630
# 46   M      564
# 45   F      497
# 47   M      482
# 50   M      480
#            ...
# 74   F        2
# 81   M        2
# 77   F        1
# 83   M        1
# 84   F        1
# Length: 125, dtype: int64

# %%
marathon_2017_clean['Senior'] = marathon_2017_clean.Age > 60

# %%
marathon_2017_clean.head()
# Out:
#                Name  Age M/F           City State Country Citizen       5K  \
# 0   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN  0:15:25
# 1       Rupp, Galen   30   M       Portland    OR     USA     NaN  0:15:24
# 2     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN  0:15:25
# 3  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN  0:15:25
# 4    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN  0:15:25
#
#        10K      15K  ...      30K      35K      40K     Pace Proj Time  \
# 0  0:30:28  0:45:44  ...  1:33:01  1:48:19  2:02:53  0:04:57         -
# 1  0:30:27  0:45:44  ...  1:33:01  1:48:19  2:03:14  0:04:58         -
# 2  0:30:29  0:45:44  ...  1:33:01  1:48:31  2:03:38  0:04:59         -
# 3  0:30:29  0:45:44  ...  1:33:01  1:48:58  2:04:35  0:05:03         -
# 4  0:30:28  0:45:44  ...  1:33:01  1:48:41  2:05:00  0:05:04         -
#
#   Official Time Overall Gender Division  Senior
# ...

# %% [markdown]
# 3 Ways of Adding new columns to Pandas dataframe
#
# https://re-thought.com/how-to-add-new-columns-in-a-dataframe-in-pandas/
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 1: By declaring a new list as a column
marathon_2017_clean['Year'] = '2017'

# %%
marathon_2017_clean.head()
# Out:
#                Name  Age M/F           City State Country Citizen       5K  \
# 0   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN  0:15:25
# 1       Rupp, Galen   30   M       Portland    OR     USA     NaN  0:15:24
# 2     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN  0:15:25
# 3  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN  0:15:25
# 4    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN  0:15:25
#
#        10K      15K  ...      35K      40K     Pace Proj Time Official Time  \
# 0  0:30:28  0:45:44  ...  1:48:19  2:02:53  0:04:57         -       2:09:37
# 1  0:30:27  0:45:44  ...  1:48:19  2:03:14  0:04:58         -       2:09:58
# 2  0:30:29  0:45:44  ...  1:48:31  2:03:38  0:04:59         -       2:10:28
# 3  0:30:29  0:45:44  ...  1:48:58  2:04:35  0:05:03         -       2:12:08
# 4  0:30:28  0:45:44  ...  1:48:41  2:05:00  0:05:04         -       2:12:35
#
#   Overall Gender Division Senior  Year
# ...

# %%
# 2: Using .loc[]
marathon_2017_clean.loc[:,'Year'] = '2017'

# %%
marathon_2017_clean.head()
# Out:
#                Name  Age M/F           City State Country Citizen       5K  \
# 0   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN  0:15:25
# 1       Rupp, Galen   30   M       Portland    OR     USA     NaN  0:15:24
# 2     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN  0:15:25
# 3  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN  0:15:25
# 4    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN  0:15:25
#
#        10K      15K  ...      35K      40K     Pace Proj Time Official Time  \
# 0  0:30:28  0:45:44  ...  1:48:19  2:02:53  0:04:57         -       2:09:37
# 1  0:30:27  0:45:44  ...  1:48:19  2:03:14  0:04:58         -       2:09:58
# 2  0:30:29  0:45:44  ...  1:48:31  2:03:38  0:04:59         -       2:10:28
# 3  0:30:29  0:45:44  ...  1:48:58  2:04:35  0:05:03         -       2:12:08
# 4  0:30:28  0:45:44  ...  1:48:41  2:05:00  0:05:04         -       2:12:35
#
#   Overall Gender Division Senior  Year
# ...

# %%
# 3: Using the .assign() function
marathon_2017_clean = marathon_2017_clean.assign(Year='2017')

# %%
marathon_2017_clean.head()
# Out:
#                Name  Age M/F           City State Country Citizen       5K  \
# 0   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN  0:15:25
# 1       Rupp, Galen   30   M       Portland    OR     USA     NaN  0:15:24
# 2     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN  0:15:25
# 3  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN  0:15:25
# 4    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN  0:15:25
#
#        10K      15K  ...      35K      40K     Pace Proj Time Official Time  \
# 0  0:30:28  0:45:44  ...  1:48:19  2:02:53  0:04:57         -       2:09:37
# 1  0:30:27  0:45:44  ...  1:48:19  2:03:14  0:04:58         -       2:09:58
# 2  0:30:29  0:45:44  ...  1:48:31  2:03:38  0:04:59         -       2:10:28
# 3  0:30:29  0:45:44  ...  1:48:58  2:04:35  0:05:03         -       2:12:08
# 4  0:30:28  0:45:44  ...  1:48:41  2:05:00  0:05:04         -       2:12:35
#
#   Overall Gender Division Senior  Year
# ...

# %%
marathon_2017_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           26410 non-null  object
#  1   Age            26410 non-null  int64
#  2   M/F            26410 non-null  object
#  3   City           26410 non-null  object
#  4   State          22815 non-null  object
#  5   Country        26410 non-null  object
#  6   Citizen        1254 non-null   object
#  7   5K             26410 non-null  object
#  8   10K            26410 non-null  object
#  9   15K            26410 non-null  object
#  10  20K            26410 non-null  object
#  11  Half           26410 non-null  object
#  12  25K            26410 non-null  object
#  13  30K            26410 non-null  object
#  14  35K            26410 non-null  object
#  15  40K            26410 non-null  object
#  16  Pace           26410 non-null  object
# ...

# %% [markdown]
# #6. Convert Data

# %%
# 1. User defined Function
# Define function name to_seconds
def to_seconds(record):
    hms = record.str.split(':', n=2, expand=True)
    return hms[0].astype(int) * 3600 + hms[1].astype(int) * 60 + hms[2].astype(int)

# Call user defined function to_seconds
marathon_2017_clean['Official Time Sec'] = to_seconds(marathon_2017_clean['Official Time'])

# %%
marathon_2017_clean.head()
# Out:
#                Name  Age M/F           City State Country Citizen       5K  \
# 0   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN  0:15:25
# 1       Rupp, Galen   30   M       Portland    OR     USA     NaN  0:15:24
# 2     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN  0:15:25
# 3  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN  0:15:25
# 4    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN  0:15:25
#
#        10K      15K  ...      40K     Pace Proj Time Official Time Overall  \
# 0  0:30:28  0:45:44  ...  2:02:53  0:04:57         -       2:09:37       1
# 1  0:30:27  0:45:44  ...  2:03:14  0:04:58         -       2:09:58       2
# 2  0:30:29  0:45:44  ...  2:03:38  0:04:59         -       2:10:28       3
# 3  0:30:29  0:45:44  ...  2:04:35  0:05:03         -       2:12:08       4
# 4  0:30:28  0:45:44  ...  2:05:00  0:05:04         -       2:12:35       5
#
#   Gender Division Senior  Year  Official Time Sec
# ...

# %%
# 2. Pre defined Function
# Import Numpy Library and call it as np
import numpy as np

# %%
# Convert using pandas to_timedelta method
marathon_2017['Official Time Sec'] = pd.to_timedelta(marathon_2017['Official Time'])

# %%
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:33:01  1:48:19  2:02:53  0:04:57         -
# 1     NaN        NaN  ...  1:33:01  1:48:19  2:03:14  0:04:58         -
# 2     NaN        NaN  ...  1:33:01  1:48:31  2:03:38  0:04:59         -
# 3     NaN        NaN  ...  1:33:01  1:48:58  2:04:35  0:05:03         -
# 4     NaN        NaN  ...  1:33:01  1:48:41  2:05:00  0:05:04         -
#
#   Official Time Overall Gender Division Official Time Sec
# ...

# %%
marathon_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26410 non-null  int64
#  1   Bib                26410 non-null  object
#  2   Name               26410 non-null  object
#  3   Age                26410 non-null  int64
#  4   M/F                26410 non-null  object
#  5   City               26410 non-null  object
#  6   State              22815 non-null  object
#  7   Country            26410 non-null  object
#  8   Citizen            1254 non-null   object
#  9   Unnamed: 9         91 non-null     object
#  10  5K                 26410 non-null  object
#  11  10K                26410 non-null  object
#  12  15K                26410 non-null  object
#  13  20K                26410 non-null  object
#  14  Half               26410 non-null  object
#  15  25K                26410 non-null  object
# ...

# %%
# Convert time to seconds value using astype method
marathon_2017['Official Time Sec'] = marathon_2017['Official Time Sec'].astype('m8[s]').astype(np.int64)

# %%
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:33:01  1:48:19  2:02:53  0:04:57         -
# 1     NaN        NaN  ...  1:33:01  1:48:19  2:03:14  0:04:58         -
# 2     NaN        NaN  ...  1:33:01  1:48:31  2:03:38  0:04:59         -
# 3     NaN        NaN  ...  1:33:01  1:48:58  2:04:35  0:05:03         -
# 4     NaN        NaN  ...  1:33:01  1:48:41  2:05:00  0:05:04         -
#
#   Official Time Overall Gender Division Official Time Sec
# ...

# %%
marathon_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26410 non-null  int64
#  1   Bib                26410 non-null  object
#  2   Name               26410 non-null  object
#  3   Age                26410 non-null  int64
#  4   M/F                26410 non-null  object
#  5   City               26410 non-null  object
#  6   State              22815 non-null  object
#  7   Country            26410 non-null  object
#  8   Citizen            1254 non-null   object
#  9   Unnamed: 9         91 non-null     object
#  10  5K                 26410 non-null  object
#  11  10K                26410 non-null  object
#  12  15K                26410 non-null  object
#  13  20K                26410 non-null  object
#  14  Half               26410 non-null  object
#  15  25K                26410 non-null  object
# ...

# %% [markdown]
# #7. Sort, Group and Save Data

# %%
marathon_2015 = pd.read_csv('/gdrive/My Drive/data/marathon_results_2015.csv')
marathon_2016 = pd.read_csv('/gdrive/My Drive/data/marathon_results_2016.csv')
marathon_2017 = pd.read_csv('/gdrive/My Drive/data/marathon_results_2017.csv')

# %%
marathon_2015_2017 = pd.concat([marathon_2015, marathon_2016, marathon_2017],ignore_index=True, sort=False)

# %%
marathon_2015_2017.describe()
# Out:
#          Unnamed: 0           Age       Overall        Gender      Division
# count  53008.000000  79638.000000  79638.000000  79638.000000  79638.000000
# mean   13251.666692     42.415166  13273.683417   6693.365064   1618.782792
# std     7651.406646     11.355453   7663.512720   3927.594786   1448.369424
# min        0.000000     18.000000      1.000000      1.000000      1.000000
# 25%     6625.750000     34.000000   6637.250000   3319.000000    510.000000
# 50%    13251.500000     42.000000  13273.500000   6637.000000   1179.500000
# 75%    19877.250000     50.000000  19910.000000   9955.000000   2219.000000
# max    26597.000000     84.000000  26629.000000  14581.000000   6004.000000

# %%
marathon_2015_2017.head()
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
#   Official Time Overall Gender Division Unnamed: 8
# ...

# %%
marathon_2015_2017.sort_values(by=['Age'], ascending=False)
# Out:
#        Unnamed: 0    Bib                 Name  Age M/F          City State  \
# 79568     26340.0  25269    Beiers, Katherine   84   F    Santa Cruz    CA
# 50448         NaN  25878       Wilson, Harold   83   M         Tyler    TX
# 52761         NaN  26142    Beiers, Katherine   83   F    Santa Cruz    CA
# 75847     22619.0  25134            Yoo, Jack   83   M       Chicago    IL
# 21625     21625.0  24564       Wilson, Harold   82   M         Tyler    TX
# ...           ...    ...                  ...  ...  ..           ...   ...
# 48969         NaN  29566    Bailey, Jordan E.   18   F        Quincy    MA
# 57963      4735.0   4496        Moore, Ryan D   18   M    North Bend    WA
# 3885       3885.0   6992  Altomari, Collin P.   18   M  Severna Park    MD
# 3857       3857.0  30062  Chhokra, Shubhankar   18   M     Cambridge    MA
# 69159     15931.0  30496   Pohl, Elizabeth S.   18   F        Weston    MA
#
# ...

# %%
groupby_Age = marathon_2017_clean['Official Time Sec'].groupby(marathon_2017_clean.Age)

# %%
groupby_Age.head()
# Out:
# 0         7777
# 1         7798
# 2         7828
# 3         7928
# 4         7955
#          ...
# 25691    20151
# 26076    21051
# 26266    21538
# 26335    21823
# 26340    21847
# Name: Official Time Sec, Length: 314, dtype: int64

# %%
groupby_Age.mean()
# Out:
# Age
# 18    15486.000000
# 19    15230.813953
# 20    14253.891566
# 21    13783.795918
# 22    14196.833333
#           ...
# 79    16774.333333
# 80    16410.333333
# 81    18240.000000
# 83    17079.000000
# 84    21847.000000
# Name: Official Time Sec, Length: 66, dtype: float64

# %%
groupby_Age.min()
# Out:
# Age
# 18    11720
# 19     8831
# 20     9201
# 21     9070
# 22     9097
#       ...
# 79    14606
# 80    15250
# 81    16691
# 83    17079
# 84    21847
# Name: Official Time Sec, Length: 66, dtype: int64

# %%
output_file = '/gdrive/My Drive/data/marathon_2015_2017.csv'
marathon_2015_2017.to_csv(output_file, index=None, header=True)
